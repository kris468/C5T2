# %% [markdown]
# # Course 5 / Task 2 - Exploratory Data Analysis

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
credit = pd.read_csv('default of credit card clients.csv', header = 1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
credit = credit.rename(columns = {"default payment next month":"default"})

# %%
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default'],
#       dtype='object')

# %%
credit.columns[credit.isnull().any()].tolist()
# Out:
# []

# %% [markdown]
# No missing values identified in any of the features(columns) for this dataset.

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
#     Discretize Limit_Bal and Age features for easier interpretation later.

# %%
creditLimits = ["Small","Medium","Large","Super"]
credit["LIMIT_BAL_CAT"] = pd.cut(credit["LIMIT_BAL"],[9999,50000,250000,500000,1000001],labels = creditLimits)
creditAge = ["YoungAdults","MiddleAge","Elders"]
credit["AGE_CAT"] = pd.cut(credit["AGE"],[20,35,55,80],labels = creditAge)

# %%
credit.groupby('LIMIT_BAL_CAT')['LIMIT_BAL_CAT'].count()
# Out:
# LIMIT_BAL_CAT
# Small      7676
# Medium    15607
# Large      6511
# Super       206
# Name: LIMIT_BAL_CAT, dtype: int64

# %%
credit.groupby('AGE_CAT')['AGE_CAT'].count()
# Out:
# AGE_CAT
# YoungAdults    16809
# MiddleAge      12347
# Elders           844
# Name: AGE_CAT, dtype: int64

# %% [markdown]
# Majority of customers are under age of 55 (almost 97.2 percent).

# %%
credit.groupby('EDUCATION')['EDUCATION'].count()
# Out:
# EDUCATION
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# Name: EDUCATION, dtype: int64

# %% [markdown]
# Customers with some form of education (high school and beyond) comprise more than 98 percent of loans.

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 27 columns):
# ID               30000 non-null int64
# LIMIT_BAL        30000 non-null int64
# SEX              30000 non-null int64
# EDUCATION        30000 non-null int64
# MARRIAGE         30000 non-null int64
# AGE              30000 non-null int64
# PAY_0            30000 non-null int64
# PAY_2            30000 non-null int64
# PAY_3            30000 non-null int64
# PAY_4            30000 non-null int64
# PAY_5            30000 non-null int64
# PAY_6            30000 non-null int64
# BILL_AMT1        30000 non-null int64
# BILL_AMT2        30000 non-null int64
# BILL_AMT3        30000 non-null int64
# BILL_AMT4        30000 non-null int64
# BILL_AMT5        30000 non-null int64
# BILL_AMT6        30000 non-null int64
# PAY_AMT1         30000 non-null int64
# PAY_AMT2         30000 non-null int64
# PAY_AMT3         30000 non-null int64
# PAY_AMT4         30000 non-null int64
# ...

# %% [markdown]
# ##     Visualizing Data

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default',
#        'LIMIT_BAL_CAT', 'AGE_CAT'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.title('Limit Balance Distribution')
plt.xlabel('Limit Balance')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
plt.title('Limit Balance Distribution')
plt.xlabel('Limit Balance')
plt.ylabel('Count')
plt.show()

# %%
credit['LIMIT_BAL_CAT'].value_counts().plot(kind='bar')
plt.title('Limit Balance Distribution By Categories')
plt.xlabel('Limit Balance')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The number of loans (limit balance) in 50,000-2,50,000 range is almost equal to the sum of all loans in the remaining loan ranges.

# %%
credit['SEX'].value_counts().plot(kind='bar')
plt.title('LOAN DISTRIBUTION BY GENDER')
plt.xlabel('Gender')
a=[0,1]
plt.xticks(a,('Female','Male'))
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#     More number of loan applicants are female compared to male. The ratio is nearly 1.5.

# %%
credit['EDUCATION'].value_counts().plot(kind='bar')
plt.title('LOAN DISTRIBUTION BY EDUCATION LEVEL')
plt.xlabel('EDUCATION LEVEL')
a=[0,1,2,3,4,5,6]
plt.xticks(a,('University','College','HighSchool','Others1','Others2','Others3','Others4'))
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Majority of loan applicants have higher education with atleast college education level. The number of loan customers with    no education background is very insignificant.

# %%
credit['MARRIAGE'].value_counts().plot(kind='bar')
plt.title('LOAN DISTRIBUTION BY MARITAL STATUS')
plt.xlabel('MARITAL STATUS')
a=[0,1,2,3]
plt.xticks(a,('Single','Married','Divorce','Others'))
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#     Most loan customers are single, closely followed by married customers. Other categories are insignificant in comparison.

# %%
credit['AGE_CAT'].value_counts().plot(kind='bar')
plt.title('LOAN DISTRIBUTION BY AGE')
plt.xlabel('AGE')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#     Majority of loans are held by young and middle aged adults (21-55 years). Older customers are very few in comparison.

# %%
# Limit balance basis for loans that are at default
credit.groupby(['LIMIT_BAL_CAT', 'default'])['LIMIT_BAL_CAT'].count()
# Out:
# LIMIT_BAL_CAT  default
# Small          0           5236
#                1           2440
# Medium         0          12348
#                1           3259
# Large          0           5597
#                1            914
# Super          0            183
#                1             23
# Name: LIMIT_BAL_CAT, dtype: int64

# %%
# Use seaborn to group by Limit balance and default payment
g = sns.catplot('default', data=credit, hue='LIMIT_BAL_CAT', kind='count', aspect=1.75)
g.set_xlabels('default payment next month')
a=[0,1]
plt.xticks(a,('No Default','Default'))
# Out:
# ([<matplotlib.axis.XTick at 0x18270090160>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %% [markdown]
# Smaller loans (10k-50K) have higher proportion of defaults followed by medium loans (50K-250K).

# %%
# Number of male and female customers who default on loans
credit.groupby(['SEX', 'default'])['SEX'].count()
# Out:
# SEX  default
# 1    0           9015
#      1           2873
# 2    0          14349
#      1           3763
# Name: SEX, dtype: int64

# %%
# Use seaborn to group by Sex and default payment
g = sns.catplot('default', data=credit, hue='SEX', kind='count', aspect=1.75)
g.set_xlabels('default payment next month')
a=[0,1]
plt.xticks(a,('No Default','Default'))
# Out:
# ([<matplotlib.axis.XTick at 0x18270123048>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %% [markdown]
# Larger proportion of male customers (1) -24% tend to default on the payments compared to female customers (2) - 20.8%.

# %%
# Educated customers who default on loans
credit.groupby(['EDUCATION', 'default'])['EDUCATION'].count()
# Out:
# EDUCATION  default
# 0          0             14
# 1          0           8549
#            1           2036
# 2          0          10700
#            1           3330
# 3          0           3680
#            1           1237
# 4          0            116
#            1              7
# 5          0            262
#            1             18
# 6          0             43
#            1              8
# Name: EDUCATION, dtype: int64

# %%
# Use seaborn to group by Education and default payment
g = sns.catplot('default', data=credit, hue='EDUCATION', kind='count', aspect=1.75)
g.set_xlabels('default payment next month')
a=[0,1]
plt.xticks(a,('No Default','Default'))
# Out:
# ([<matplotlib.axis.XTick at 0x1826ffef668>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %% [markdown]
# Larger proportion of customers educated till high school (3) tend to default on their loans compared to other higher        education levels.

# %%
# Marital status basis for customers who default on loans
credit.groupby(['MARRIAGE', 'default'])['MARRIAGE'].count()
# Out:
# MARRIAGE  default
# 0         0             49
#           1              5
# 1         0          10453
#           1           3206
# 2         0          12623
#           1           3341
# 3         0            239
#           1             84
# Name: MARRIAGE, dtype: int64

# %%
# Use seaborn to group by marriage and default payment
g = sns.catplot('default', data=credit, hue='MARRIAGE', kind='count', aspect=1.75)
g.set_xlabels('default payment next month')
a=[0,1]
plt.xticks(a,('No Default','Default'))
# Out:
# ([<matplotlib.axis.XTick at 0x1826e9b02b0>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %% [markdown]
# It can be clearly seen that Single(2) and Married(1) customers have majority of loans. Also, it is clear that married and       divorced customers tend to default at higher proportion of loans compared to other marital status.

# %%
# Age basis for customers who default on loans
credit.groupby(['AGE_CAT', 'default'])['AGE_CAT'].count()
# Out:
# AGE_CAT      default
# YoungAdults  0          13212
#              1           3597
# MiddleAge    0           9532
#              1           2815
# Elders       0            620
#              1            224
# Name: AGE_CAT, dtype: int64

# %%
# Use seaborn to group by age and default payment
g = sns.catplot('default', data=credit, hue='AGE_CAT', kind='count', aspect=1.75)
g.set_xlabels('default payment next month')
a=[0,1]
plt.xticks(a,('No Default','Default'))
# Out:
# ([<matplotlib.axis.XTick at 0x1827048d240>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %% [markdown]
# Overall, more number of customers who take loans are young adults(21-35) or middle aged (35-55). However, the proportion of     loans defaulted increase with age.

# %%
plt.plot(credit['LIMIT_BAL'])
plt.title('Limit Balance Range')
plt.xlabel('Loan ID')
plt.ylabel('Limit Balance')
plt.show()

# %% [markdown]
# Majority of loans seem to be below 500K. Just one loan has a limit balance of 1million.

# %%
fig1 = plt.figure(figsize=(14,10))

ax1 = fig1.add_subplot(221)
ax1.set_title('BILL_AMT1 Range')
ax1.set_xlabel('Loan ID')
ax1.set_ylabel('BILL_AMT1')
plt.plot(credit['BILL_AMT1'])

ax2 = fig1.add_subplot(222)
ax2.set_title('BILL_AMT2 Range')
ax2.set_xlabel('Loan ID')
ax2.set_ylabel('BILL_AMT2')
plt.plot(credit['BILL_AMT2'])

ax3 = fig1.add_subplot(223)
ax3.set_title('BILL_AMT3 Range')
ax3.set_xlabel('Loan ID')
ax3.set_ylabel('BILL_AMT3')
plt.plot(credit['BILL_AMT3'])

ax4 = fig1.add_subplot(224)
ax4.set_title('BILL_AMT4 Range')
ax4.set_xlabel('Loan ID')
ax4.set_ylabel('BILL_AMT4')
plt.plot(credit['BILL_AMT4'])

fig2 = plt.figure(figsize=(14,10))

ax5 = fig2.add_subplot(221)
ax5.set_title('BILL_AMT5 Range')
ax5.set_xlabel('Loan ID')
ax5.set_ylabel('BILL_AMT5')
plt.plot(credit['BILL_AMT5'])

ax6 = fig2.add_subplot(222)
ax6.set_title('BILL_AMT6 Range')
ax6.set_xlabel('Loan ID')
ax6.set_ylabel('BILL_AMT6')
plt.plot(credit['BILL_AMT6'])

# %% [markdown]
# Bill statements from certain months (April, June, July, September) have credit amounts indicated by large negative values.

# %%
x = credit['PAY_0']
y = credit['PAY_2']
plt.scatter(x,y, alpha=0.3)
plt.title('Repayment Status - September,2005 vs August,2005')
plt.xlabel('Repayment - September,2005')
plt.ylabel('Repayment - August,2005')
plt.show()

# %% [markdown]
# Above scatter plot indicates that there might be some kind of correlation between payment status for August and September.

# %%
sns.stripplot(x='PAY_0', y='PAY_2', data=credit, size=8, jitter=True, edgecolor='none', alpha=.40)
sns.despine()

# %%
y = credit['EDUCATION']
x = credit['default']
plt.scatter(x,y, alpha=0.8)
plt.title('Default Next Month vs Education')
plt.xlabel('Education')
plt.ylabel('Default Payment Next Month')
plt.show()

# %%
sns.stripplot(x='default', y='EDUCATION', data=credit, size=8, jitter=True, edgecolor='none', alpha=.40)
sns.despine()

# %% [markdown]
# More defaults with education level, the loan percentage carried by these levels is high too.

# %%
fig1 = plt.figure(figsize=(14,10))

ax1 = fig1.add_subplot(221)
ax1.set_title('BILL_AMT1 Box Plot')
ax1.set_xlabel('Loan ID')
ax1.set_ylabel('BILL_AMT1')
plt.boxplot(credit['BILL_AMT1'],0,'gD')

ax2 = fig1.add_subplot(222)
ax2.set_title('BILL_AMT2 Box Plot')
ax2.set_xlabel('Loan ID')
ax2.set_ylabel('BILL_AMT2')
plt.boxplot(credit['BILL_AMT2'],0,'gD')

ax3 = fig1.add_subplot(223)
ax3.set_title('BILL_AMT3 Box Plot')
ax3.set_xlabel('Loan ID')
ax3.set_ylabel('BILL_AMT3')
plt.boxplot(credit['BILL_AMT3'],0,'gD')

ax4 = fig1.add_subplot(224)
ax4.set_title('BILL_AMT4 Box Plot')
ax4.set_xlabel('Loan ID')
ax4.set_ylabel('BILL_AMT4')
plt.boxplot(credit['BILL_AMT4'],0,'gD')

fig2 = plt.figure(figsize=(14,10))

ax5 = fig2.add_subplot(221)
ax5.set_title('BILL_AMT5 Box Plot')
ax5.set_xlabel('Loan ID')
ax5.set_ylabel('BILL_AMT5')
plt.boxplot(credit['BILL_AMT5'],0,'gD')

ax6 = fig2.add_subplot(222)
ax6.set_title('BILL_AMT6 Box Plot')
ax6.set_xlabel('Loan ID')
ax6.set_ylabel('BILL_AMT6')
plt.boxplot(credit['BILL_AMT6'],0,'gD')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1827290ad30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x182729146d8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1827290abe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x18272914d68>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18272914e48>],
#  'means': []}

# %%
A = credit['LIMIT_BAL']
plt.boxplot(A,0,'gD')
plt.title('Limit Balance Box Plot')
plt.xlabel('')
plt.ylabel('Limit Balance')
plt.show()

# %% [markdown]
# Above box plots for bill amounts indicate presence of outlier data points which might not help with prediction later.

# %%
# Number of customers who defaulted next month payment based on gender and marital status
credit.pivot_table('default', 'SEX', 'MARRIAGE', aggfunc=np.sum, margins=True)
# Out:
# MARRIAGE  0     1     2   3   All
# SEX
# 1         2  1346  1485  40  2873
# 2         3  1860  1856  44  3763
# All       5  3206  3341  84  6636

# %% [markdown]
# More number of females in customers who defaulted but it is in-line with more number of total female customers.

# %%
#Number of loans that are not at default payment for next month
not_default = credit[credit['default']==0]
len(not_default)
# Out:
# 23364

# %%
# Number of customers who did not defaulted next month payment based on gender and marital status
not_default.pivot_table('default', 'SEX', 'MARRIAGE', aggfunc=len, margins=True)
# Out:
# MARRIAGE   0      1      2    3    All
# SEX
# 1         12   3844   5068   91   9015
# 2         37   6609   7555  148  14349
# All       49  10453  12623  239  23364

# %%
# Customers who did and didnot default based on gender and marriage
table = pd.crosstab(index=[credit['default'],credit.MARRIAGE], columns=[credit.SEX])
table.unstack()
# Out:
# SEX        1                   2
# MARRIAGE   0     1     2   3   0     1     2    3
# default
# 0         12  3844  5068  91  37  6609  7555  148
# 1          2  1346  1485  40   3  1860  1856   44

# %%
table.columns, table.index
# Out:
# (Int64Index([1, 2], dtype='int64', name='SEX'),
#  MultiIndex(levels=[[0, 1], [0, 1, 2, 3]],
#             labels=[[0, 0, 0, 0, 1, 1, 1, 1], [0, 1, 2, 3, 0, 1, 2, 3]],
#             names=['default', 'MARRIAGE']))

# %%
# Change name of columns
table.index.set_levels(['No Default', 'Default'], level=0, inplace=True)
table.index.set_levels(['Others','Married','Single','Divorced'], level=1, inplace=True)
table.columns = ['Male','Female']
table
# Out:
#                      Male  Female
# default    MARRIAGE
# No Default Others      12      37
#            Married   3844    6609
#            Single    5068    7555
#            Divorced    91     148
# Default    Others       2       3
#            Married   1346    1860
#            Single    1485    1856
#            Divorced    40      44

# %% [markdown]
# More male customers who are divorced tend to default (close to 45%).

# %%
# Distribution of age, with an overlay of a density plot
age_dist = sns.distplot(credit['AGE'])
age_dist.set_title("Distribution of Customers' Ages")
# Out:
# Text(0.5, 1.0, "Distribution of Customers' Ages")

# %%
# Customers who did or did not default payments based on sex and age group
g = sns.catplot('AGE_CAT', data=credit, kind='count', hue='SEX', col='default', legend = False, aspect=1.25, size=5)
plt.legend(title='Gender', loc='upper left', labels=['Male', 'Female'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3692: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Distribution of Limit balance grouped by default
fig = sns.FacetGrid(credit, hue='default', aspect=4)
fig.map(sns.kdeplot, 'LIMIT_BAL', shade=True)
oldest = credit.LIMIT_BAL.max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Limit Balance Grouped by Default')
fig.set(label=('No Default', 'Default'))
fig.add_legend()

# %% [markdown]
# More number of defaults on loan happen at lower limit balances.

# %%
#Distribution of Age grouped by default
fig = sns.FacetGrid(credit, hue='default', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit.AGE.max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped by Default')
fig.set(label=('No Default', 'Default'))
fig.add_legend()

# %% [markdown]
# Age doesnt seem to have a significant bearing on the tendency to default or not default a loan payment.

# %%
corrMat = credit.corr()
redCorrMat = corrMat[abs(corrMat)>0.5]
print(corrMat)
# Out:
#                  ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID         1.000000   0.026179  0.018497   0.039177 -0.029079  0.018678
# LIMIT_BAL  0.026179   1.000000  0.024755  -0.219161 -0.108139  0.144713
# SEX        0.018497   0.024755  1.000000   0.014232 -0.031389 -0.090874
# EDUCATION  0.039177  -0.219161  0.014232   1.000000 -0.143464  0.175061
# MARRIAGE  -0.029079  -0.108139 -0.031389  -0.143464  1.000000 -0.414170
# AGE        0.018678   0.144713 -0.090874   0.175061 -0.414170  1.000000
# PAY_0     -0.030575  -0.271214 -0.057643   0.105364  0.019917 -0.039447
# PAY_2     -0.011215  -0.296382 -0.070771   0.121566  0.024199 -0.050148
# PAY_3     -0.018494  -0.286123 -0.066096   0.114025  0.032688 -0.053048
# PAY_4     -0.002735  -0.267460 -0.060173   0.108793  0.033122 -0.049722
# PAY_5     -0.022199  -0.249411 -0.055064   0.097520  0.035629 -0.053826
# PAY_6     -0.020270  -0.235195 -0.044008   0.082316  0.034345 -0.048773
# ...

# %%
sns.heatmap(corrMat, 
            xticklabels=corrMat.columns.values,
            yticklabels=corrMat.columns.values)

# %% [markdown]
# The matrix indicates mostly positive correlation (limit at 1) rather than inverse relationships (limit less than -0.5). Payment status and bill statements tend have higher level of correlations among themselves.

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                      ID     LIMIT_BAL          SEX     EDUCATION     MARRIAGE  \
# ID         7.500250e+07  2.941664e+07    78.356379    268.154338  -131.452515
# LIMIT_BAL  2.941664e+07  1.683446e+10  1571.050630 -22474.028945 -7323.669658
# SEX        7.835638e+01  1.571051e+03     0.239247      0.005502    -0.008014
# EDUCATION  2.681543e+02 -2.247403e+04     0.005502      0.624651    -0.059184
# MARRIAGE  -1.314525e+02 -7.323670e+03    -0.008014     -0.059184     0.272452
# AGE        1.491057e+03  1.730767e+05    -0.409726      1.275380    -1.992764
# PAY_0     -2.975726e+02 -3.954593e+04    -0.031685      0.093584     0.011683
# PAY_2     -1.162770e+02 -4.603765e+04    -0.041442      0.115025     0.015122
# PAY_3     -1.916922e+02 -4.443225e+04    -0.038694      0.107861     0.020421
# PAY_4     -2.769132e+01 -4.057181e+04    -0.034411      0.100528     0.020213
# PAY_5     -2.178600e+02 -3.667056e+04    -0.030521      0.087340     0.021074
# ...

# %%
#Remove unwanted variables
credit2 = credit.drop(['ID','LIMIT_BAL','AGE'],axis=1)
credit2.rename(columns={"LIMIT_BAL_CAT":"LIMIT_BAL","AGE_CAT":"AGE"},inplace = True)
clist = ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
       'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default']
credit2 = credit2[clist]
credit2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
# LIMIT_BAL    30000 non-null category
# SEX          30000 non-null int64
# EDUCATION    30000 non-null int64
# MARRIAGE     30000 non-null int64
# AGE          30000 non-null category
# PAY_0        30000 non-null int64
# PAY_2        30000 non-null int64
# PAY_3        30000 non-null int64
# PAY_4        30000 non-null int64
# PAY_5        30000 non-null int64
# PAY_6        30000 non-null int64
# BILL_AMT1    30000 non-null int64
# BILL_AMT2    30000 non-null int64
# BILL_AMT3    30000 non-null int64
# BILL_AMT4    30000 non-null int64
# BILL_AMT5    30000 non-null int64
# BILL_AMT6    30000 non-null int64
# PAY_AMT1     30000 non-null int64
# PAY_AMT2     30000 non-null int64
# PAY_AMT3     30000 non-null int64
# PAY_AMT4     30000 non-null int64
# PAY_AMT5     30000 non-null int64
# PAY_AMT6     30000 non-null int64
# default      30000 non-null int64
# ...

# %%
#Use one-hot encoding for categorical variables
cat_columns = ["LIMIT_BAL","AGE"]
credit2 = pd.get_dummies(credit2,columns = cat_columns, prefix = ["LIMITBAL","AGEGROUP"])
credit2.columns
# Out:
# Index(['SEX', 'EDUCATION', 'MARRIAGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4',
#        'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4',
#        'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
#        'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default', 'LIMITBAL_Small',
#        'LIMITBAL_Medium', 'LIMITBAL_Large', 'LIMITBAL_Super',
#        'AGEGROUP_YoungAdults', 'AGEGROUP_MiddleAge', 'AGEGROUP_Elders'],
#       dtype='object')

# %%
#Rearrange columns of dataframe
clist = ['LIMITBAL_Small','LIMITBAL_Medium', 'LIMITBAL_Large', 'LIMITBAL_Super','AGEGROUP_YoungAdults', 
         'AGEGROUP_MiddleAge', 'AGEGROUP_Elders','SEX', 'EDUCATION', 'MARRIAGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4',
       'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4',
       'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
       'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default']
credit2 = credit2[clist]
credit2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 29 columns):
# LIMITBAL_Small          30000 non-null uint8
# LIMITBAL_Medium         30000 non-null uint8
# LIMITBAL_Large          30000 non-null uint8
# LIMITBAL_Super          30000 non-null uint8
# AGEGROUP_YoungAdults    30000 non-null uint8
# AGEGROUP_MiddleAge      30000 non-null uint8
# AGEGROUP_Elders         30000 non-null uint8
# SEX                     30000 non-null int64
# EDUCATION               30000 non-null int64
# MARRIAGE                30000 non-null int64
# PAY_0                   30000 non-null int64
# PAY_2                   30000 non-null int64
# PAY_3                   30000 non-null int64
# PAY_4                   30000 non-null int64
# PAY_5                   30000 non-null int64
# PAY_6                   30000 non-null int64
# BILL_AMT1               30000 non-null int64
# BILL_AMT2               30000 non-null int64
# ...

# %%
#Write the pre-processed data frame "credit2' to csv file
credit2.to_csv(r'Preprocessed_DefaultData.csv')
